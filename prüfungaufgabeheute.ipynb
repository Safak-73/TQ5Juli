# %%
def berechne_rabatt(betrag):
    if betrag < 100:
        rabatt_prozent = 0
    elif betrag < 500:
        rabatt_prozent = 5
    elif betrag < 1000:
        rabatt_prozent = 10
    else:
        rabatt_prozent = 15
    rabatt_betrag = betrag * rabatt_prozent / 100
    endbetrag = betrag - rabatt_betrag


    print(f"Einkaufswert: {betrag:.2f} €")
    print(f"Rabatt: {rabatt_prozent} %")
    print(f"Endbetrag: {endbetrag:.2f} €")

    return endbetrag

# %%
berechne_rabatt(80)     # 0 % Rabatt
berechne_rabatt(300)    # 5 % Rabatt
berechne_rabatt(750)    # 10 % Rabatt
berechne_rabatt(1200)
# Out:
# Einkaufswert: 80.00 €
# Rabatt: 0 %
# Endbetrag: 80.00 €
# Einkaufswert: 300.00 €
# Rabatt: 5 %
# Endbetrag: 285.00 €
# Einkaufswert: 750.00 €
# Rabatt: 10 %
# Endbetrag: 675.00 €
# Einkaufswert: 1200.00 €
# Rabatt: 15 %
# Endbetrag: 1020.00 €
# 1020.0

# %%
wort=('bitte ein wort eingeben')
neuwort=[]

for i in rang
    neuwort.append(i)
    print(neuwort)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 neuwort=""
#       3 index=len(wort)-1
# ----> 4 for i in index:
#       5     neuwort.append(i)
#       6     print(neuwort)
#
# TypeError: 'int' object is not iterable
