# %% [markdown]
# ## Anleitung
# # 1.Liste dein aktuelles Arbeitsverzeichnis auf
# # 2. Erstelle und lösche anschließend einen neuen Ordner in deinem aktuellen Arbbeitsverzeichnis.
# # 3. gib infos über de aktuell angemeldeten Benutzer aus

# %%
import os
 
aktuelles_verzeichnis = os.getcwd()
 
print("Aktuelles Arbeitsverzeichnis:", aktuelles_verzeichnis)
# Out:
# Aktuelles Arbeitsverzeichnis: c:\Users\mytq\Documents\GitHub\TQ5Juli\python

# %%
import os
 
ordner_name = "4.september"
 
try:
    os.mkdir(ordner_name)
    print(f"Ordner '{ordner_name}' wurde erstellt.")
except FileExistsError:
    print(f"Ordner '{ordner_name}' existiert bereits.")
 
 
os.rmdir(ordner_name)
print(f"Ordner '{ordner_name}' wurde gelöscht.")
# Out:
# Ordner '4.september' wurde erstellt.
# Ordner '4.september' wurde gelöscht.

# %%
import os
 
benutzer = os.getlogin()
 
print("Aktuell angemeldeter Benutzer:", benutzer)
# Out:
# Aktuell angemeldeter Benutzer: mytq

# %% [markdown]
# # Anleitung
# ## Verwende das JSON-Modul, um  die Historie frühere Durchläufe zu speichern  und abzurufen:
#  a. Erstelle helloworld.py
#  b. Importiere das json-Modul
#  c. Schreibe Daten in eine Datei
#  d. Untersuche die Datei
#  ## VErwende die if-Anweisung zur Steuerung des PRogrammablaufs:
#  a. Aktualisiere helloworld.
