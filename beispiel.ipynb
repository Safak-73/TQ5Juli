# %%
import random
random.seed()
a=random.randint(1,10)
b=random.randint(1,10)

c=a+b
print(f"{a}+{b}")
zahl=c+1
versuch=0
zahl
# Out:
# 3+10

# %%
einkaufliste=[]

while True:

    aktion = input("möctst du artikel hinfügen oder löschen oder anzeigen oder beenden ? hinfügen\ entfernen\ anzeigen \beenden").lower()
    if aktion=='hinfügen':
        artikel=input("welche artikel hinfügen möchtest:").lower()
        einkaufliste.append(artikel)
        print(einkaufliste)
    elif aktion=='entfernen':
        artikel=input('welche artikel entfernen möchtest:')
        if artikel in einkaufliste:
            einkaufliste.remove(artikel)
            print('artikel wurde gelöscht') 
        else:
            print('artikel wurde nicht gefunden')       
    elif aktion=='anzeigen':
        print('einkauflist anzeigen') 
        print(einkaufliste)  
    elif aktion=='beenden':
        print('ende') 
        break
# Out:
# ['banane']
# ['banane', 'apfel']
# ['banane', 'apfel', 'milch']
# artikel wurde gelöscht
# einkauflist anzeigen
# ['banane', 'apfel']
# ende

# %%
def erstelle_brett():
    brett = []
    
    for i in range(3):
     zeile = [" "," "," "]
     brett.append(zeile)
    return brett   

def drucke_brett(brett):
   for zeile in brett:
      print("|". join(zeile))
      print("------")
drucke_brett(erstelle_brett())

def zug_machen(brett,spieler,zeile,spalte):
   if brett[zeile][spalte]== " ":
      brett[zeile][spalte]=spieler
      return True
   else:
      return False   

def spiele_tic_tac_toe():
   brett =erstelle_brett()
   akteul_spiele = "x"
   while True:
      drucke_brett(brett)
      try:
        zeile =int(input(f"spieler {akteul_spiele}, wäle deine zeile(0-2)"))
        spalte =int(input(f"spieler {akteul_spiele}, wäle deine zeile(0-2)"))
      except:
           print('ungultig ,versuch erneut')
           
           continue
      if zeile not in [0,1,2] or spalte not in [0,1,2]:
            print("Ungültige Eingabe! Nur 0, 1 oder 2 erlaubt.")
            continue  
      if not zug_machen(brett, akteul_spiele,zeile, spalte):
            print("Feld schon belegt, versuch nochmal!")
            continue
   
      aktueller_spieler = "O" if aktueller_spieler == "X" else "X"
       

spiele_tic_tac_toe()
# Out:
#  | |
# ------
#  | |
# ------
#  | |
# ------
#  | |
# ------
#  | |
# ------
#  | |
# ------
#  |x|
# ------
#  | |
# ------
#  | |
# ------
#  |x|
# ------
#  | |
# ------
# x| |
# ------
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# Feld schon belegt, versuch nochmal!
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ------
# ungultig ,versuch erneut
#  |x|
# ------
# x| |
# ------
# x| |
# ...

# %% [markdown]
# pseudecode
# PROZEDURE größere_zahlen(a,b)
#   a:=5
#   b:=7
#   WENN a > b DANN
#    AUSGABE a
#   SONST
#    AUSGABE B
#   ENDE WENN
#
# ENDE PROZEDURE

# %% [markdown]
# PROZEDURE noten_durchschnitt()
#   list :=[]
#   AUSGABE:= 'wie viel noten möchten sie eingeben'
#   EINGABE n
#  summe := 0
#  SOLANGE TRUE
#  ZÄHLE i von 1 BIS n
#    AUSGABE "'geben sie die',i, note ein:"
#    EINGABE note
#    summe:= summe + note
#  ENDE ZÄHLE
#
#  durchscnitt := summe /n
#  AUSGABE durchschnitt
# ENDE PROZEDURE

# %% [markdown]
# PROZEDURE zahl_uberprüft(zahl)
#   AUSGABE 'welche zahl möchten sie eingeben'
#   EINGABE zahl
#   WENN zahl / 2 :=0 DANN
#     AUSGABE zahl
#   SONNST WENN zahl /2 <> 0
#     AUSGABE 'ungerade ZAHL  ist zahl'
#   ENDE WENN
# ENDE PROZEDURE

# %% [markdown]
# PROZEDURE drei_zahlen()
#  AUSGABE 'bitte geben sie drei zahlen'
#  EINGABE a,b,c
#  WENN a< b UND a< C DANN
#   AUSGABE 'a ist kleinste zahl'
#  ANSONSTEN WENN a<> b DANN
#   AUSGABE  'a ist nicht kleinste'
#  ANSONSTEN WENN b < a UND b< c DANN
#   AUSGABE 'b ist kleinste'
#  SONST
#    AUSGABE 'keine lösung'
#
#  ENDE WENN
# ENDE PROZEDURE

# %% [markdown]
# PROZEDURE wechselgeld()
#  AUSGABE 'bitte geben sie preise in euro ein'
#  EINGABE preis
#
#  AUSGABE "Geben Sie den bezahlten Betrag ein (in Euro):"
#  EINGABE bezahlt
#
#  wechselgeld := bezahlt-preis
